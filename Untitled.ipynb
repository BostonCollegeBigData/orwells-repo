# %%
import pandas as pd

# %%
import numpy as np
import matplotlib as plt

# %%
df = read_csv("/Users/orwellandrade/Downloads/Summary Data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d074d96244c1> in <module>()
# ----> 1 df = read_csv("/Users/orwellandrade/Downloads/Summary Data.csv")
#
# NameError: name 'read_csv' is not defined

# %%
df = pd.read_csv("/Users/orwellandrade/Downloads/Summary Data.csv")

# %%
df.describe()
# Out:
#             mill_id         jobid    email_open  email_open_sum         click  \
# count  2.150188e+07  2.150188e+07  2.150188e+07    2.150188e+07  2.150188e+07
# mean   1.633459e+06  8.203179e+05  2.739753e-01    3.090823e-01  2.610688e-02
# std    1.142560e+08  4.861892e+05  4.459964e-01    7.531269e-01  1.594532e-01
# min    1.130000e+02  4.786000e+03  0.000000e+00    0.000000e+00  0.000000e+00
# 25%    7.673900e+04  3.920720e+05  0.000000e+00    0.000000e+00  0.000000e+00
# 50%    2.053400e+05  8.306500e+05  0.000000e+00    0.000000e+00  0.000000e+00
# 75%    3.245740e+05  1.235235e+06  1.000000e+00    1.000000e+00  0.000000e+00
# max    1.000000e+10  1.762434e+06  1.000000e+00    9.520000e+02  1.000000e+00
#
#           click_sum        bounce   unsubscribe        mobile       desktop
# count  2.150188e+07  2.150188e+07  2.150188e+07  2.150188e+07  2.150188e+07
# mean   3.555382e-02  9.087113e-03  7.663516e-04  1.477840e-01  1.360170e-01
# ...

# %%
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c11d00573bc0> in <module>()
# ----> 1 df.head(20)
#
# NameError: name 'df' is not defined

# %%
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c11d00573bc0> in <module>()
# ----> 1 df.head(20)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c11d00573bc0> in <module>()
# ----> 1 df.head(20)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6fae94b3c442> in <module>()
# ----> 1 df.head(10)
#
# NameError: name 'df' is not defined

# %%
head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-1f8160d6a4c8> in <module>()
# ----> 1 head(10)
#
# NameError: name 'head' is not defined

# %%
df.head(20)
# Out:
#     mill_id    jobid                  date_sent        date_sent_redef  \
# 0      9060  1395677  03/15/2016  8:01:20:217AM   3/15/2016 8:01:20 AM
# 1     69428   261890  08/02/2014  7:04:03:700AM    8/2/2014 7:04:03 AM
# 2    133570  1529442  05/03/2016  7:30:45:563AM    5/3/2016 7:30:45 AM
# 3    371933  1123798  12/02/2015  3:30:48:950PM   12/2/2015 3:30:48 PM
# 4    382802   724650  05/31/2015  3:01:11:520PM   5/31/2015 3:01:11 PM
# 5    404474   670499  04/29/2015  6:01:29:030PM   4/29/2015 6:01:29 PM
# 6    348181  1041654  11/02/2015 12:01:43:580PM  11/3/2015 12:01:43 AM
# 7    240111    59309  01/04/2014  9:01:00:263AM    1/4/2014 9:01:00 AM
# 8    241243  1339197  02/23/2016  9:01:11:930AM   2/23/2016 9:01:11 AM
# 9      9232  1582107  05/23/2016  1:00:44:793PM   5/23/2016 1:00:44 PM
# 10    40231   836163  07/31/2015  8:01:15:293AM   7/31/2015 8:01:15 AM
# 11   140441    78932  02/01/2014  8:01:10:640AM    2/1/2014 8:01:10 AM
# ...

# %%
df = pd.read_csv("/Users/orwellandrade/Documents/BC grad courses/big data course/WORK_WCAS_DATA_CLASS.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-11-4419d0eb8193> in <module>()
# ----> 1 df = pd.read_csv("/Users/orwellandrade/Documents/BC grad courses/big data course/WORK_WCAS_DATA_CLASS.csv")
#
# ...

# %%
df = pd.read_csv("/Users/orwellandrade/Documents/BC grad courses/big data course/wcas donor dataset small.csv")
# Out:
# //anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(10)
# Out:
#    household_id  constituent_id constituent_type ugrad_school  ugrad_year  \
# 0          1039            1039           Alumni         MCAS      1954.0
# 1          1040            1040           Alumni         CSOM      1953.0
# 2          1042            1042           Alumni          NaN         NaN
# 3          1043            1043           Alumni          NaN         NaN
# 4          1044            1044           Alumni          NaN         NaN
# 5          1045            1045           Alumni          NaN         NaN
# 6          1046            1046           Alumni          NaN         NaN
# 7          1047            1047           Alumni          NaN         NaN
# 8          1048            1048           Alumni          NaN         NaN
# 9          1049            1049           Alumni          NaN         NaN
#
#    law_degree  law_year  cgsom_degree  cgsom_year  cgson_degree     ...       \
# 0           0       NaN             0         NaN             0     ...
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         household_id  constituent_id constituent_type ugrad_school  \
# 0               1039            1039           Alumni         MCAS
# 1               1040            1040           Alumni         CSOM
# 2               1042            1042           Alumni          NaN
# 3               1043            1043           Alumni          NaN
# 4               1044            1044           Alumni          NaN
# 5               1045            1045           Alumni          NaN
# 6               1046            1046           Alumni          NaN
# 7               1047            1047           Alumni          NaN
# 8               1048            1048           Alumni          NaN
# 9               1049            1049           Alumni          NaN
# 10              1050            1050           Alumni          NaN
# 11              1051            1051           Alumni         MCAS
# ...

# %%
df['lifetime_cash'].hist(bins=50)

# %%
# %matplotlib inline

# %%
df['lifetime_cash'].hist(bins=50)

# %%
df['lifetime_cash'].hist(bins=10)

# %%
df['ltw_cash'].hist(bins=10)

# %%
df['ltw_cash'].hist(bins=10) if 'ltw_cash'>100
# Out:
#   File "<ipython-input-22-6937cbda21cf>", line 1
#     df['ltw_cash'].hist(bins=10) if 'ltw_cash'>100
#                                                   ^
# SyntaxError: invalid syntax

# %%
if 'ltw_cash' > 50 df['ltw_cash'].hist(bins=10)
# Out:
#   File "<ipython-input-23-7ad99773d291>", line 1
#     if 'ltw_cash' > 50 df['ltw_cash'].hist(bins=10)
#                         ^
# SyntaxError: invalid syntax

# %%
if 'ltw_cash' > 50 
    df['ltw_cash'].hist(bins=10)
# Out:
#   File "<ipython-input-24-2f36e90b07c7>", line 1
#     if 'ltw_cash' > 50
#                        ^
# SyntaxError: invalid syntax

# %%
df ln['ltw_cash'].hist(bins=10)
# Out:
#   File "<ipython-input-25-9114fd4ffb0d>", line 1
#     df ln['ltw_cash'].hist(bins=10)
#         ^
# SyntaxError: invalid syntax

# %%
import math

# %%
df.describe()
# Out:
# //anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#         household_id  constituent_id     ugrad_year     law_degree  \
# count  197710.000000   197710.000000  135539.000000  197710.000000
# mean   141687.429427   137518.348161    1985.092748       0.076258
# std    111716.769323   108508.626533      20.537777       0.265411
# min      1039.000000     1039.000000    1901.000000       0.000000
# 25%     52154.000000    51721.250000            NaN       0.000000
# 50%    104043.500000   102104.500000            NaN       0.000000
# 75%    237316.750000   230672.750000            NaN       0.000000
# max    455574.000000   450756.000000    2016.000000       1.000000
#
#            law_year   cgsom_degree    cgsom_year   cgson_degree   cgson_year  \
# count  15077.000000  197710.000000  12181.000000  197710.000000  3548.000000
# ...

# %%
math.log10(ltw_cash)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-9e4abb6d0273> in <module>()
# ----> 1 math.log10(ltw_cash)
#
# NameError: name 'ltw_cash' is not defined

# %%
df['ltw_cash'].hist(data, bins=np.logspace(0.1, 1.0, 50))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-13342886daa3> in <module>()
# ----> 1 df['ltw_cash'].hist(data, bins=np.logspace(0.1, 1.0, 50))
#
# NameError: name 'data' is not defined

# %%
df['ltw_cash'].hist(bins=np.logspace(0.1, 1.0, 50))

# %%
df['ltw_cash'].hist(bins=np.logspace(0.1, 10, 50))

# %%
df['ltw_cash'].hist(bins=np.logspace(0.1, 1.0, 50))
